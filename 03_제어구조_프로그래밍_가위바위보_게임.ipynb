# %% [markdown]
# <a href="https://colab.research.google.com/github/jjieun0129/python-class/blob/main/03_%EC%A0%9C%EC%96%B4%EA%B5%AC%EC%A1%B0_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_%EA%B0%80%EC%9C%84%EB%B0%94%EC%9C%84%EB%B3%B4_%EA%B2%8C%EC%9E%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 오늘의 주제: 제어구조의 응용 - 가위바위보 게임
#
# ## ✅ 학습 목표
# - 다양한 제어 구조를 활용하여 생활 속 문제 해결을 위한 프로그램을 작성할 수 있다.
#
# ## 📘 핵심 개념 요약
# - 조건문: 조건에 따라 프로그램의 흐름을 제어하는 구조 (`if`, `elif`, `else`)
# - 반복문: 정해진 조건 동안 계속 반복하여 실행되는 구조 (`while`, `for`)
# - break문: 반복문을 즉시 종료
# - continue문: 다음 반복으로 넘어감

# %% [markdown]
# #가위바위보 게임

# %% [markdown]
# ![가위바위보.png](data:image/png;base64,...)

# %% [markdown]
# ## 🧑‍💻 실습 코드
# ---

# %%
import random

choices = ["가위", "바위", "보"]
user_choice = ""
computer_choice = ""
user_win = 0
computer_win = 0

while True:
    user_choice = input("가위, 바위, 보 중 하나를 선택하세요: ")
    if user_choice not in choices:
        print("올바른 선택이 아닙니다. 다시 입력해주세요.")
        continue

    computer_choice = random.choice(choices)
    print(f"<나: {user_choice}, 컴퓨터: {computer_choice}>")

    if (user_choice == "가위" and computer_choice == "보") or (user_choice == "바위" and computer_choice == "가위") or (user_choice == "보" and computer_choice == "바위"):
        print("이겼습니다! Good~!! (게임 계속..)\n")
        user_win += 1
    elif user_choice == computer_choice:
        print("비겼습니다. (게임 계속..)\n")
    else:
        print("컴퓨터 승리! 게임을 종료합니다.\n")
        computer_win += 1
        break

print(f"최종 전적 - 나: {user_win}승 / 컴퓨터: {computer_win}승")

# %% [markdown]
# ## 📝 오늘 배운 점 정리
# - ex) 조건문과 반복문을 실제 게임에 적용할 수 있다는 걸 느꼈다.
# - ex) `break`, `continue`를 사용해서 흐름 제어하는 방식이 흥미로웠다.

# %% [markdown]
# ## 📌 나의 생각 or 질문 (자유롭게 작성해 보세요!)
# - 오늘 수업에서 어려웠던 점은?
#
# - 내가 만든 가위바위보 게임에 추가하고 싶은 기능은?
